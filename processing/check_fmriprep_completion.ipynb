# %% [markdown]
# # Evaluate completion of fMRIPrep on datasets

# %%
import os.path as op
from glob import glob

import pandas as pd

# %%
# Constants
project_dir = "/home/data/nbc/misc-projects/Salo_PowerReplication/"

dsets = {
    "dset-camcan": [
        "{sub}.html",
        "{sub}/func/{sub}_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz",
        "{sub}/func/{sub}_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz",
        "{sub}/func/{sub}_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz",
        "{sub}/func/{sub}_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz",
        "{sub}/func/{sub}_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz",
    ],
    "dset-cambridge": [
        "{sub}.html",
        "{sub}/func/{sub}_task-rest_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz",
        "{sub}/func/{sub}_task-rest_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz",
        "{sub}/func/{sub}_task-rest_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz",
        "{sub}/func/{sub}_task-rest_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz",
    ],
    "dset-dupre": [
        "{sub}.html",
        "{sub}/func/{sub}_task-rest_run-1_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz",
        "{sub}/func/{sub}_task-rest_run-1_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz",
        "{sub}/func/{sub}_task-rest_run-1_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz",
    ],
    "dset-dalenberg": [
        "{sub}.html",
        "{sub}/func/{sub}_task-images_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz",
        "{sub}/func/{sub}_task-images_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz",
        "{sub}/func/{sub}_task-images_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz",
    ],
    "dset-cohen": [
        "{sub}.html",
        "{sub}/func/{sub}_task-bilateralfingertapping_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz",
        "{sub}/func/{sub}_task-bilateralfingertapping_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz",
        "{sub}/func/{sub}_task-bilateralfingertapping_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz",
        "{sub}/func/{sub}_task-bilateralfingertapping_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz",
    ],
}

# %%
# Find failed subjects
for dset, target_files in dsets.items():
    print(dset)
    dset_dir = op.join(project_dir, dset)
    deriv_dir = op.join(dset_dir, "derivatives/fmriprep/")
    if not op.isdir(deriv_dir):
        print("\tDataset not yet processed.")
        continue

    participants_file = op.join(dset_dir, "participants.tsv")
    participants_df = pd.read_table(participants_file)
    subject_list = participants_df["participant_id"].tolist()
    failed_subjects = []
    for sub in subject_list:
        tfs = [op.join(deriv_dir, temp.format(sub=sub)) for temp in target_files]
        if not all(op.isfile(tf) for tf in tfs):
            failed_subjects.append(sub)

    if failed_subjects:
        print("\t" + "\n\t".join(failed_subjects))
    
    if dset == "dset-camcan":
        camcan_failed = failed_subjects
# Out:
# dset-camcan
# 	sub-CC120409
# 	sub-CC120469
# 	sub-CC120470
# 	sub-CC120550
# 	sub-CC120640
# 	sub-CC120727
# 	sub-CC120764
# 	sub-CC120795
# 	sub-CC221585
# 	sub-CC410243
# 	sub-CC410248
# 	sub-CC410251
# 	sub-CC410284
# 	sub-CC410287
# 	sub-CC410289
# 	sub-CC410297
# 	sub-CC410323
# 	sub-CC510076
# 	sub-CC510086
# 	sub-CC510115
# 	sub-CC510161
# 	sub-CC510163
# 	sub-CC510208
# 	sub-CC510220
# 	sub-CC510226
# 	sub-CC510473
# 	sub-CC510474
# 	sub-CC510486
# 	sub-CC510534
# 	sub-CC510548
# 	sub-CC510551
# 	sub-CC510568
# 	sub-CC510609
# 	sub-CC610631
# 	sub-CC610658
# 	sub-CC610671
# 	sub-CC620005
# 	sub-CC620026
# 	sub-CC620044
# 	sub-CC620073
# 	sub-CC620085
# 	sub-CC620821
# 	sub-CC620919
# 	sub-CC621184
# 	sub-CC621199
# 	sub-CC621248
# 	sub-CC621284
# 	sub-CC621642
# dset-cambridge
# dset-dupre
# dset-dalenberg
# dset-cohen

# %%
# Find the missing files
for dset, target_files in dsets.items():
    print(dset)
    dset_dir = op.join(project_dir, dset)
    deriv_dir = op.join(dset_dir, "derivatives/fmriprep/")
    if not op.isdir(deriv_dir):
        print("\tDataset not yet processed.")
        continue

    participants_file = op.join(dset_dir, "participants.tsv")
    participants_df = pd.read_table(participants_file)
    subject_list = participants_df["participant_id"].tolist()
    failed_subjects = []
    for sub in subject_list:
        tfs = [op.join(deriv_dir, temp.format(sub=sub)) for temp in target_files]
        for tf in tfs:
            if not op.isfile(tf):
                print("\t{}".format(op.basename(tf)))
# Out:
# dset-camcan
# 	sub-CC120409.html
# 	sub-CC120409_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120409_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120409_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120409_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120409_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120469.html
# 	sub-CC120469_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120469_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120469_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120469_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120469_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120470.html
# 	sub-CC120470_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120470_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120470_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120470_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120470_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120550.html
# 	sub-CC120550_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120550_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120550_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120550_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120550_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120640.html
# 	sub-CC120640_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120640_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120640_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120640_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120640_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120727.html
# 	sub-CC120727_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120727_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120727_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120727_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120727_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120764.html
# 	sub-CC120764_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120764_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120764_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120764_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120764_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120795.html
# 	sub-CC120795_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120795_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120795_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120795_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC120795_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC221585.html
# 	sub-CC221585_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC221585_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC221585_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC221585_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC221585_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410243.html
# 	sub-CC410243_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410243_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410243_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410243_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410243_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410248.html
# 	sub-CC410248_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410248_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410248_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410248_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410248_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410251.html
# 	sub-CC410251_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410251_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410251_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410251_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410251_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410284.html
# 	sub-CC410284_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410284_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410284_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410284_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410284_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410287.html
# 	sub-CC410287_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410287_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410287_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410287_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410287_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410289.html
# 	sub-CC410289_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410289_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410289_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410289_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410289_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410297.html
# 	sub-CC410297_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410297_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410297_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410297_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410297_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410323.html
# 	sub-CC410323_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410323_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410323_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410323_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC410323_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510076.html
# 	sub-CC510076_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510076_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510076_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510076_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510076_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510086.html
# 	sub-CC510086_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510086_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510086_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510086_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510086_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510115.html
# 	sub-CC510115_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510115_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510115_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510115_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510115_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510161.html
# 	sub-CC510161_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510161_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510161_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510161_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510161_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510163.html
# 	sub-CC510163_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510163_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510163_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510163_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510163_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510208.html
# 	sub-CC510208_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510208_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510208_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510208_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510208_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510220.html
# 	sub-CC510220_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510220_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510220_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510220_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510220_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510226.html
# 	sub-CC510226_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510226_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510226_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510226_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510226_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510473.html
# 	sub-CC510473_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510473_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510473_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510473_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510473_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510474.html
# 	sub-CC510474_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510474_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510474_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510474_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510474_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510486.html
# 	sub-CC510486_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510486_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510486_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510486_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510486_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510534.html
# 	sub-CC510534_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510534_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510534_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510534_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510534_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510548.html
# 	sub-CC510548_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510548_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510548_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510548_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510548_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510551.html
# 	sub-CC510551_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510551_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510551_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510551_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510551_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510568.html
# 	sub-CC510568_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510568_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510568_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510568_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510568_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510609.html
# 	sub-CC510609_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510609_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510609_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510609_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC510609_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC610631.html
# 	sub-CC610631_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC610631_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC610631_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC610631_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC610631_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC610658.html
# 	sub-CC610658_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC610658_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC610658_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC610658_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC610658_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC610671.html
# 	sub-CC610671_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC610671_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC610671_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC610671_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC610671_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620005.html
# 	sub-CC620005_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620005_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620005_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620005_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620005_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620026.html
# 	sub-CC620026_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620026_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620026_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620026_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620026_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620044.html
# 	sub-CC620044_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620044_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620044_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620044_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620044_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620073.html
# 	sub-CC620073_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620073_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620073_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620073_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620073_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620085.html
# 	sub-CC620085_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620085_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620085_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620085_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620085_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620821.html
# 	sub-CC620821_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620821_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620821_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620821_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620821_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620919.html
# 	sub-CC620919_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620919_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620919_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620919_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC620919_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC621184.html
# 	sub-CC621184_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC621184_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC621184_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC621184_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC621184_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC621199.html
# 	sub-CC621199_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC621199_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC621199_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC621199_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC621199_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC621248.html
# 	sub-CC621248_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC621248_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC621248_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC621248_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC621248_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC621284.html
# 	sub-CC621284_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC621284_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC621284_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC621284_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC621284_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC621642.html
# 	sub-CC621642_task-movie_echo-1_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC621642_task-movie_echo-2_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC621642_task-movie_echo-3_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC621642_task-movie_echo-4_space-scanner_desc-partialPreproc_bold.nii.gz
# 	sub-CC621642_task-movie_echo-5_space-scanner_desc-partialPreproc_bold.nii.gz
# dset-cambridge
# dset-dupre
# dset-dalenberg
# dset-cohen

# %% [markdown]
# ## Clean up the working directory for CamCAN

# %%
raise Exception()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-5-32c500991385> in <module>
# ----> 1 raise Exception()
#
# Exception:

# %%
participants_file = op.join(project_dir, "dset-camcan", "participants.tsv")
participants_df = pd.read_table(participants_file)

# %%
len(camcan_failed)
# Out:
# 48

# %%
subs = participants_df["participant_id"].tolist()
camcan_successful = sorted(list(set(subs) - set(camcan_failed)))
len(camcan_successful)
# Out:
# 594

# %%
idx = [str(subs.index(f) + 1) for f in camcan_failed]
print(",".join(idx))
# Out:
# 36,38,39,40,41,42,43,44,132,283,284,285,286,287,288,289,290,359,360,361,362,363,364,365,366,388,389,392,393,394,395,396,397,490,492,493,494,495,496,497,498,545,547,553,554,555,556,557

# %%
from shutil import rmtree

wf_dir = "/scratch/nbc/tsalo006/Salo_PowerReplication/dset-camcan/fmriprep-20.2.1/fmriprep_wf"
for sub in camcan_successful:
    sub_name = sub.split("-")[1]
    sub_dir = f"single_subject_{sub_name}_wf"
    sub_wf_dir = op.join(wf_dir, sub_dir)
    if op.isdir(sub_wf_dir):
        rmtree(sub_wf_dir)
    else:
        print(f"Not removing {sub_name}")
# Out:
# Not removing CC110033
# Not removing CC110037
# Not removing CC110045
# Not removing CC110056
# Not removing CC110069
# Not removing CC110087
# Not removing CC110098
# Not removing CC110101
# Not removing CC110126
# Not removing CC110174
# Not removing CC110182
# Not removing CC110187
# Not removing CC110319
# Not removing CC110411
# Not removing CC110606
# Not removing CC112141
# Not removing CC120008
# Not removing CC120049
# Not removing CC120061
# Not removing CC120065
# Not removing CC120120
# Not removing CC120123
# Not removing CC120166
# Not removing CC120182
# Not removing CC120208
# Not removing CC120218
# Not removing CC120234
# Not removing CC120264
# Not removing CC120276
# Not removing CC120286
# Not removing CC120309
# Not removing CC120313
# Not removing CC120319
# Not removing CC120347
# Not removing CC120376
# Not removing CC120462
# Not removing CC120816
# Not removing CC120987
# Not removing CC121106
# Not removing CC121111
# Not removing CC121144
# Not removing CC121158
# Not removing CC121194
# Not removing CC121200
# Not removing CC121317
# Not removing CC121397
# Not removing CC121411
# Not removing CC121428
# Not removing CC121479
# Not removing CC121685
# Not removing CC121795
# Not removing CC122172
# Not removing CC122405
# Not removing CC122620
# Not removing CC210023
# Not removing CC210051
# Not removing CC210088
# Not removing CC210124
# Not removing CC210148
# Not removing CC210172
# Not removing CC210182
# Not removing CC210250
# Not removing CC210304
# Not removing CC210314
# Not removing CC210422
# Not removing CC210519
# Not removing CC210526
# Not removing CC210617
# Not removing CC210657
# Not removing CC212153
# Not removing CC220098
# Not removing CC220107
# Not removing CC220115
# Not removing CC220132
# Not removing CC220151
# Not removing CC220198
# Not removing CC220203
# Not removing CC220223
# Not removing CC220232
# Not removing CC220234
# Not removing CC220284
# Not removing CC220323
# Not removing CC220335
# Not removing CC220352
# Not removing CC220372
# Not removing CC220394
# Not removing CC220419
# Not removing CC220506
# Not removing CC220518
# Not removing CC220519
# Not removing CC220526
# Not removing CC220535
# Not removing CC220567
# Not removing CC220610
# Not removing CC220635
# Not removing CC220697
# Not removing CC220713
# Not removing CC220806
# Not removing CC220828
# Not removing CC220843
# Not removing CC220901
# Not removing CC220920
# Not removing CC220974
# Not removing CC220999
# Not removing CC221002
# Not removing CC221031
# Not removing CC221033
# Not removing CC221038
# Not removing CC221040
# Not removing CC221054
# Not removing CC221107
# Not removing CC221209
# Not removing CC221220
# Not removing CC221244
# Not removing CC221324
# Not removing CC221336
# Not removing CC221352
# Not removing CC221373
# Not removing CC221487
# Not removing CC221511
# Not removing CC221527
# Not removing CC221565
# Not removing CC221580
# Not removing CC221595
# Not removing CC221648
# Not removing CC221733
# Not removing CC221740
# Not removing CC221755
# Not removing CC221775
# Not removing CC221828
# Not removing CC221886
# Not removing CC221935
# Not removing CC221954
# Not removing CC221977
# Not removing CC221980
# Not removing CC222120
# Not removing CC222125
# Not removing CC222185
# Not removing CC222258
# Not removing CC222264
# Not removing CC222304
# Not removing CC222326
# Not removing CC222367
# Not removing CC222496
# Not removing CC222555
# Not removing CC222652
# Not removing CC222797
# Not removing CC222956
# Not removing CC223085
# Not removing CC223286
# Not removing CC310008
# Not removing CC310051
# Not removing CC310052
# Not removing CC310086
# Not removing CC310129
# Not removing CC310135
# Not removing CC310142
# Not removing CC310160
# Not removing CC310203
# Not removing CC310214
# Not removing CC310224
# Not removing CC310252
# Not removing CC310256
# Not removing CC310331
# Not removing CC310361
# Not removing CC310385
# Not removing CC310391
# Not removing CC310397
# Not removing CC310402
# Not removing CC310407
# Not removing CC310410
# Not removing CC310414
# Not removing CC310450
# Not removing CC310463
# Not removing CC310473
# Not removing CC312058
# Not removing CC312222
# Not removing CC320002
# Not removing CC320022
# Not removing CC320059
# Not removing CC320088
# Not removing CC320089
# Not removing CC320107
# Not removing CC320109
# Not removing CC320160
# Not removing CC320202
# Not removing CC320206
# Not removing CC320218
# Not removing CC320267
# Not removing CC320269
# Not removing CC320297
# Not removing CC320321
# Not removing CC320325
# Not removing CC320336
# Not removing CC320342
# Not removing CC320359
# Not removing CC320417
# Not removing CC320429
# Not removing CC320448
# Not removing CC320461
# Not removing CC320478
# Not removing CC320500
# Not removing CC320553
# Not removing CC320568
# Not removing CC320574
# Not removing CC320575
# Not removing CC320576
# Not removing CC320608
# Not removing CC320616
# Not removing CC320621
# Not removing CC320636
# Not removing CC320651
# Not removing CC320661
# Not removing CC320680
# Not removing CC320686
# Not removing CC320687
# Not removing CC320698
# Not removing CC320759
# Not removing CC320776
# Not removing CC320814
# Not removing CC320850
# Not removing CC320870
# Not removing CC320888
# Not removing CC320893
# Not removing CC320904
# Not removing CC321000
# Not removing CC321025
# Not removing CC321069
# Not removing CC321073
# Not removing CC321087
# Not removing CC321107
# Not removing CC321137
# Not removing CC321154
# Not removing CC321174
# Not removing CC321203
# Not removing CC321281
# Not removing CC321291
# Not removing CC321331
# Not removing CC321368
# Not removing CC321428
# Not removing CC321431
# Not removing CC321464
# Not removing CC321504
# Not removing CC321506
# Not removing CC321529
# Not removing CC321544
# Not removing CC321557
# Not removing CC321585
# Not removing CC321594
# Not removing CC321595
# Not removing CC321880
# Not removing CC321899
# Not removing CC321976
# Not removing CC322186
# Not removing CC410015
# Not removing CC410040
# Not removing CC410084
# Not removing CC410086
# Not removing CC410091
# Not removing CC410094
# Not removing CC410097
# Not removing CC410101
# Not removing CC410113
# Not removing CC410119
# Not removing CC410121
# Not removing CC410169
# Not removing CC410173
# Not removing CC410177
# Not removing CC410179
# Not removing CC410182
# Not removing CC410220
# Not removing CC410222
# Not removing CC410226
# Not removing CC410325
# Not removing CC410354
# Not removing CC410387
# Not removing CC410390
# Not removing CC410432
# Not removing CC412004
# Not removing CC412021
# Not removing CC420004
# Not removing CC420060
# Not removing CC420061
# Not removing CC420071
# Not removing CC420075
# Not removing CC420089
# Not removing CC420091
# Not removing CC420094
# Not removing CC420100
# Not removing CC420137
# Not removing CC420143
# Not removing CC420148
# Not removing CC420149
# Not removing CC420157
# Not removing CC420162
# Not removing CC420167
# Not removing CC420173
# Not removing CC420180
# Not removing CC420182
# Not removing CC420197
# Not removing CC420198
# Not removing CC420202
# Not removing CC420204
# Not removing CC420217
# Not removing CC420222
# Not removing CC420226
# Not removing CC420229
# Not removing CC420231
# Not removing CC420236
# Not removing CC420241
# Not removing CC420259
# Not removing CC420260
# Not removing CC420261
# Not removing CC420286
# Not removing CC420322
# Not removing CC420324
# Not removing CC420348
# Not removing CC420356
# Not removing CC420383
# Not removing CC420392
# Not removing CC420396
# Not removing CC420402
# Not removing CC420412
# Not removing CC420433
# Not removing CC420435
# Not removing CC420454
# Not removing CC420462
# Not removing CC420464
# Not removing CC420493
# Not removing CC420566
# Not removing CC420582
# Not removing CC420587
# Not removing CC420589
# Not removing CC420623
# Not removing CC420729
# Not removing CC420776
# Not removing CC420888
# Not removing CC510015
# Not removing CC510039
# Not removing CC510043
# Not removing CC510050
# Not removing CC510237
# Not removing CC510242
# Not removing CC510243
# Not removing CC510255
# Not removing CC510256
# Not removing CC510258
# Not removing CC510259
# Not removing CC510284
# Not removing CC510304
# Not removing CC510321
# Not removing CC510323
# Not removing CC510329
# Not removing CC510342
# Not removing CC510355
# Not removing CC510392
# Not removing CC510393
# Not removing CC510395
# Not removing CC510415
# Not removing CC510433
# Not removing CC510434
# Not removing CC510438
# Not removing CC510480
# Not removing CC510483
# Not removing CC510629
# Not removing CC510639
# Not removing CC510648
# Not removing CC512003
# Not removing CC520002
# Not removing CC520011
# Not removing CC520013
# Not removing CC520042
# Not removing CC520053
# Not removing CC520055
# Not removing CC520065
# Not removing CC520078
# Not removing CC520083
# Not removing CC520097
# Not removing CC520122
# Not removing CC520127
# Not removing CC520134
# Not removing CC520136
# Not removing CC520147
# Not removing CC520168
# Not removing CC520175
# Not removing CC520197
# Not removing CC520200
# Not removing CC520209
# Not removing CC520211
# Not removing CC520215
# Not removing CC520239
# Not removing CC520247
# Not removing CC520253
# Not removing CC520254
# Not removing CC520279
# Not removing CC520287
# Not removing CC520377
# Not removing CC520390
# Not removing CC520391
# Not removing CC520395
# Not removing CC520398
# Not removing CC520424
# Not removing CC520477
# Not removing CC520480
# Not removing CC520503
# Not removing CC520517
# Not removing CC520552
# Not removing CC520560
# Not removing CC520562
# Not removing CC520584
# Not removing CC520585
# Not removing CC520597
# Not removing CC520607
# Not removing CC520624
# Not removing CC520673
# Not removing CC520745
# Not removing CC520775
# Not removing CC520868
# Not removing CC520980
# Not removing CC521040
# Not removing CC610022
# Not removing CC610028
# Not removing CC610039
# Not removing CC610040
# Not removing CC610046
# Not removing CC610051
# Not removing CC610052
# Not removing CC610058
# Not removing CC610061
# Not removing CC610071
# Not removing CC610076
# Not removing CC610099
# Not removing CC610101
# Not removing CC610146
# Not removing CC610178
# Not removing CC610210
# Not removing CC610212
# Not removing CC610227
# Not removing CC610285
# Not removing CC610288
# Not removing CC610292
# Not removing CC610308
# Not removing CC610344
# Not removing CC610372
# Not removing CC610392
# Not removing CC610405
# Not removing CC610462
# Not removing CC610469
# Not removing CC610496
# Not removing CC610508
# Not removing CC610568
# Not removing CC610575
# Not removing CC610576
# Not removing CC610594
# Not removing CC610614
# Not removing CC610625
# Not removing CC610653
# Not removing CC620090
# Not removing CC620106
# Not removing CC620114
# Not removing CC620118
# Not removing CC620121
# Not removing CC620129
# Not removing CC620152
# Not removing CC620164
# Not removing CC620193
# Not removing CC620259
# Not removing CC620262
# Not removing CC620264
# Not removing CC620279
# Not removing CC620284
# Not removing CC620314
# Not removing CC620354
# Not removing CC620359
# Not removing CC620405
# Not removing CC620406
# Not removing CC620413
# Not removing CC620429
# Not removing CC620436
# Not removing CC620444
# Not removing CC620451
# Not removing CC620454
# Not removing CC620466
# Not removing CC620479
# Not removing CC620490
# Not removing CC620496
# Not removing CC620499
# Not removing CC620515
# Not removing CC620518
# Not removing CC620526
# Not removing CC620549
# Not removing CC620557
# Not removing CC620560
# Not removing CC620567
# Not removing CC620572
# Not removing CC620592
# Not removing CC620610
# Not removing CC620619
# Not removing CC620659
# Not removing CC620685
# Not removing CC620720
# Not removing CC620785
# Not removing CC620793
# Not removing CC620885
# Not removing CC620935
# Not removing CC621011
# Not removing CC621080
# Not removing CC621118
# Not removing CC621128
