# %% [markdown]
# # Plot adaptive mask
# Uses the adaptive mask from the test dataset for tedana. I had to edit the code to output the adaptive mask to a file.

# %%
# %matplotlib inline
from nilearn import plotting
import nibabel as nib

# %%
img = nib.load('/Users/tsalo/Google Drive File Stream/'
               'My Drive/nbclab/misc/power-replication/'
               'figures/adaptive_mask.nii.gz')

# %%
plotting.plot_stat_map(img, vmax=5, alpha=0.8,
                       draw_cross=False, colorbar=True)

# %%
plotting.plot_stat_map(img, vmax=5, alpha=0.8,
                       draw_cross=False, colorbar=True,
                       output_file=('adaptive_mask.png'))
